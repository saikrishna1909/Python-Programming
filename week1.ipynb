# %%
print("Hii! I am sai")
# Out:
# Hii! I am sai

# %%
l=[1,2,3.4,'Hello']
print(l)
# Out:
# [1, 2, 3.4, 'Hello']

# %%
l.insert(0,'sai')
print(l)
# Out:
# ['sai', 'sai', 1, 2, 3.4, 'Hello']

# %%
l.append(4)
print(l)
# Out:
# ['sai', 'sai', 1, 2, 3.4, 'Hello', 4]

# %%
l1=[1,5,7]
l.extend(l1)
print(l)
# Out:
# ['sai', 'sai', 1, 2, 3.4, 'Hello', 4, 1, 5, 7]

# %%
print(len(l))
# Out:
# 10

# %%
print(l.count(2))
# Out:
# 1

# %%
print(l.index(5))
# Out:
# 8

# %%
l.remove(5)
print(l)
# Out:
# ['sai', 'sai', 1, 2, 3.4, 'Hello', 4, 1, 7]

# %%
del l[1]
print(l)
# Out:
# ['sai', 1, 2, 3.4, 'Hello', 4, 1, 7]

# %%
m=l.pop()
n=l.pop(1)
print(m)
print(n)
print(l)
# Out:
# 7
# 1
# ['sai', 2, 3.4, 'Hello', 4, 1]

# %%
import sys
print(id(l),sys.getsizeof(l))
l.extend(l1)
print(id(l),sys.getsizeof(l))
# Out:
# 140631344344912 152
# 140631344344912 152

# %%
print(l[1:2])
print(l[-1:-2])
print(l[:-1])
print(l[:])
# Out:
# [2]
# []
# ['sai', 2, 3.4, 'Hello', 4, 1, 1, 5]
# ['sai', 2, 3.4, 'Hello', 4, 1, 1, 5, 7]

# %%
#dictionaries

# %%
d = {1:'One',2:'Two',3:'Four',4:'Three'}
print(d)
# Out:
# {1: 'One', 2: 'Two', 3: 'Four', 4: 'Three'}

# %%
d2 = {(1,2,3):"One","Two","Three"}
print(d2)
# Out:
# {(1, 2, 3): ('One', 'Two', 'Three')}

# %%
print(d.keys())
print(d.values())
print(d.items())
# Out:
# dict_keys([1, 2, 3, 4])
# dict_values(['One', 'Two', 'Four', 'Three'])
# dict_items([(1, 'One'), (2, 'Two'), (3, 'Four'), (4, 'Three')])

# %%
print(d.get(2))
# Out:
# Two

# %%
d1={3:'Three'}
d.update(d1)
print(d)
d[4]='Four'
print(d)
# Out:
# {1: 'One', 2: 'Two', 3: 'Three', 4: 'Three'}
# {1: 'One', 2: 'Two', 3: 'Three', 4: 'Four'}

# %%
print(3 in d)
# Out:
# True

# %%
print(len(d))
# Out:
# 4

# %%
print(d.pop(4))
print(d)
# Out:
# Four
# {1: 'One', 2: 'Two', 3: 'Three'}

# %%
del d[3]
print(d)
# Out:
# {1: 'One', 2: 'Two'}

# %%
#tuples

# %%
t=4,5,6
print(t)
# Out:
# (4, 5, 6)

# %%
t+=1,2,3
print(t)
# Out:
# (4, 5, 6, 1, 2, 3)

# %%
print(len(t))
# Out:
# 6

# %%
print(t[3])
# Out:
# 1

# %%
print(t.count(3))
# Out:
# 1

# %%
print(t.index(4))
# Out:
# 0

# %%
t = 1,2,3
print(id(t),sys.getsizeof(t))
t = 4,5,6
print(id(t),sys.getsizeof(t))
# Out:
# 140631343854288 80
# 140631362496384 80

# %%
#sets

# %%
s = {1,2,3,3,2,5,6}
print(s)
# Out:
# {1, 2, 3, 5, 6}

# %%
print(len(s))
# Out:
# 5

# %%
s.remove(2)
print(s)
# Out:
# {1, 3, 5, 6}

# %%
s.discard(3)
print(s)
# Out:
# {1, 5, 6}

# %%
print(s.pop())
print(s)
# Out:
# 5
# {6}

# %%
#strings

# %%
s = "String"
print(s)
# Out:
# String

# %%
s+=" Operations"
print(s)
# Out:
# String Operations

# %%
s[1:3]
# Out:
# 'tr'

# %%
s[-3::-1]
# Out:
# 'irtS'

# %%
print(s.upper())
print(s.lower())
print(s.title())
# Out:
# STRING OPERATIONS
# string operations
# String Operations
